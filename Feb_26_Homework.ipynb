# %%
import numpy as np
import matplotlib.pyplot as plt
import time

# %%
# %matplotlib notebook

n_animals = 50
n_steps = 50
diffusion_speed = 0.03
speed = 0.05

x = np.ones(n_animals) * 0.5
y = np.ones(n_animals) * 0.5

vx = np.random.rand(n_animals)
vy = np.random.rand(n_animals)

fig = plt.figure(figsize=(3,3))
plt.xlim((0,1));
plt.ylim((0,1));
 
for t in range(n_steps):
    
    x += np.random.randn(n_animals)*diffusion_speed
    y += np.random.randn(n_animals)*diffusion_speed
    
    for a in range(n_animals):
        
        x = x + vx * speed
        y = y + vy * speed
        
       #Tried implementing borders with an if statement, but I kept getting errors, so I went the np.where route instead.
       # if x<0:
       #     x = -vx
       #  if y<0:
       #     y = -vy
       # if x>1:
       #     x = -vx
       # if y>1:
       #     y = -vy
        
        x = np.where(x>0, x, vx) #Borders?
        x = np.where(x<1, x, vx)
        y = np.where(y>0, y, vy)
        y = np.where(y<1, y, vy)

        plt.cla()
        plt.plot(x,y,'k.',markersize=2);
        #time.sleep(0.01)
        plt.xlim((0,1));
        plt.ylim((0,1));
        fig.canvas.draw()
    
x = np.maximum(x,1)
x = np.minimum(x,0)
y = np.maximum(y,1)
y = np.minimum(y,0)
# Out:
# <img src="data:image/png;base64,..." width="300">
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-12-e6154680fde3> in <module>
#      41         y = np.where(y<1, y, vy)
#      42
# ---> 43         plt.cla()
#      44         plt.plot(x,y,'k.',markersize=2);
#      45         #time.sleep(0.01)
#
# ~/opt/anaconda3/lib/python3.7/site-packages/matplotlib/pyplot.py in cla()
#    2491 @docstring.copy(Axes.cla)
#    2492 def cla():
# -> 2493     return gca().cla()
#    2494
#    2495
#
# ~/opt/anaconda3/lib/python3.7/site-packages/matplotlib/axes/_base.py in cla(self)
#     971         yaxis_visible = self.yaxis.get_visible()
#     972
# --> 973         self.xaxis.cla()
#     974         self.yaxis.cla()
#     975
#
# ~/opt/anaconda3/lib/python3.7/site-packages/matplotlib/axis.py in cla(self)
# ...

# %% [markdown]
# What ended up happening was that my deer were all motivated to travel like a herd to the same point, and then after they reached that point (aka the border), they panicked and stopped acting with any motivation.

# %% [markdown]
# I never got to the point where they bounced off the border. Honestly, there's probably something simple I'm forgetting.
