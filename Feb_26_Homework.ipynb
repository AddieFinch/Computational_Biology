# %%
import numpy as np
import matplotlib.pyplot as plt
import time

# %%
# %matplotlib notebook

n_animals = 50
n_steps = 50
diffusion_speed = 0.03
speed = 0.05

x = np.ones(n_animals) * 0.5
y = np.ones(n_animals) * 0.5

fig = plt.figure(figsize=(3,3))
plt.xlim((0,1));
plt.ylim((0,1));
 
for t in range(n_steps):
    x += np.random.randn(n_animals)*diffusion_speed
    y += np.random.randn(n_animals)*diffusion_speed

    for a in range(n_animals):
        
        dx = np.random.rand(n_animals)
        dy = np.random.rand(n_animals)
        x += dx * speed
        y += dy * speed
        
        x = np.where(x>0, x, dx) #This is how borders were implemented
        x = np.where(x<1, x, dx)
        y = np.where(y>0, y, dy)
        y = np.where(y<1, y, dy)

        plt.cla()
        plt.plot(x,y,'k.',markersize=2);
        #time.sleep(0.01)
        plt.xlim((0,1));
        plt.ylim((0,1));
        fig.canvas.draw()
    
x = np.maximum(x,1)
x = np.minimum(x,0)
y = np.maximum(y,1)
y = np.minimum(y,0)
# Out:
# <img src="data:image/png;base64,..." width="300">
# Exception ignored in: <function TransformNode.set_children.<locals>.<lambda> at 0x11e7be440>
# Traceback (most recent call last):
#   File "/Users/addiefinch/opt/anaconda3/lib/python3.7/site-packages/matplotlib/transforms.py", line 178, in <lambda>
#     ref = weakref.ref(self, lambda ref, sid=id(self),
# KeyboardInterrupt
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-15-58331e3a9703> in <module>
#      34         plt.xlim((0,1));
#      35         plt.ylim((0,1));
# ---> 36         fig.canvas.draw()
#      37
#      38 x = np.maximum(x,1)
#
# ~/opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_webagg_core.py in draw(self)
#     149         self._png_is_old = True
#     150         try:
# --> 151             super().draw()
#     152         finally:
# ...
